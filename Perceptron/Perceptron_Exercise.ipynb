# %% [markdown]
# # PERCEPTRON EXERCISE -13

# %%
# for loading csv files
import pandas as pd
# for plotting and visualising
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib nbagg
# %matplotlib inline
import numpy as np
import random

# %%
# loading csv files into a dataframe variable
data_file_1 = pd.read_csv('datafile1.csv', names=['x1','x2','y'])
data_file_2 = pd.read_csv('datafile2.csv', names=['x1','x2','y'])
data_file_3 = pd.read_csv('datafile3.csv', names=['x1','x2','y'])
data_file_4 = pd.read_csv('datafile4.csv', names=['x1','x2','y'])

# %% [markdown]
# ### Plotting the scatter plots

# %%
fig = plt.figure
plt.scatter(x = data_file_1[data_file_1['y']==0].x1, y = data_file_1[data_file_1['y']==0].x2, edgecolors='g', marker = 'X', label='y=0')
plt.scatter(x = data_file_1[data_file_1['y']==1].x1, y = data_file_1[data_file_1['y']==1].x2, edgecolors='m', marker = 'o', label='y=1')
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('x1 vs x2')
plt.legend()
 
plt.show()

# %%
plt.scatter(x = data_file_2[data_file_2['y']==0].x1, y = data_file_2[data_file_2['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_2[data_file_2['y']==1].x1, y = data_file_2[data_file_2['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend()
 
plt.title('x1 vs x2')
plt.show()

# %%
plt.scatter(x = data_file_3[data_file_3['y']==0].x1, y = data_file_3[data_file_3['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_3[data_file_3['y']==1].x1, y = data_file_3[data_file_3['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')
plt.xlabel('X1')
plt.title('x1 vs x2')
plt.ylabel('X2')
 
plt.legend()
plt.show()

# %%
# plt.scatter(x=data_file_3['x1'], y=data_file_3['x2'], c=data_file_3['y'])
# plt.show()

# %%
plt.scatter(x = data_file_4[data_file_4['y']==0].x1, y = data_file_4[data_file_4['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_4[data_file_4['y']==1].x1, y = data_file_4[data_file_4['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')
plt.title('x1 vs x2')
plt.xlabel('X1')
plt.ylabel('X2')
 
plt.legend()
plt.show()

# %%
# # converting the datframe to a list of rows 
# data_file_1_row = []
# for row in data_file_1.iterrows():
#     index, data = row
#     data_file_1_row.append(data.tolist())
    
# data_file_2_row = []
# for row in data_file_2.iterrows():
#     index, data = row
#     data_file_2_row.append(data.tolist())
    
# data_file_3_row = []
# for row in data_file_3.iterrows():
#     index, data = row
#     data_file_3_row.append(data.tolist())

# data_file_4_row = []
# for row in data_file_4.iterrows():
#     index, data = row
#     data_file_4_row.append(data.tolist())

# %%
# # Make a prediction with weights
# def predict(row, weights):
#     # weights = [ w1, w2, bias]
#     activation = weights[2]
#     for i in range(len(row)-1):
#         activation += weights[i] * row[i]
#     return 1.0 if activation > 0.0 else 0.0

# %% [markdown]
# ### Predict function returning the list of predicted values

# %%
# Make a prediction with weights
def predict(data_file, weights):
    data_file_matrix = data_file.as_matrix()[:, :-1]
    bias_multiplier = np.ones(len(data_file_matrix)).reshape(len(data_file_matrix))
    data_file_matrix = np.c_[data_file_matrix,bias_multiplier]
    # weights = [ w1, w2, bias]
    predicted_y = []
    activation = np.dot(data_matrix, weights)
    for i in activation:
        if i>0:
            predicted_y.append(1)
        else:
            predicted_y.append(0)
    return predicted_y

# %% [markdown]
# #### Checking predict function

# %%
# samp2 = np.ones(20)

# %%
# samp2-samp1

# %%
# # selecting random weights
# weights = np.random.random_sample([data_file_1_matrix.shape[1]])

# predicted = predict(data_file_1, weights)
# expected = data_file_1.as_matrix()[:,-1]

# for i in range(len(expected)):
#     print("Expected:", expected[i], "\tPredicted:",predicted[i])

# %%
# samp1 = predict(data_file_2, weights)

# %%
# # Estimate Perceptron weights using stochastic gradient descent
# def train_weights(train_row, learning_rate, epoch_count):
#     # selecting random initial weights
#     weights = np.random.random_sample([3])
#     weight = []
# #     print(weights)
# #     x_matrix = [train_row[0],train_row[1],1]
#     for epoch in range(epoch_count):
#         #initialising total error to be 0 for every epoch
#         total_error = 0.0
#         for row in train_row:
#             prediction = predict(row, weights)
#             # row[-1] consists of expected y values
#             error = row[-1] - prediction
#             total_error += error
            
#             # updating bias, bias = bias + lr * error
#             weights[2] = weights[2] + learning_rate * error
            
#             # updating weights
#             for i in range(len(row)-1):
#                 weights[i] = weights[i] + learning_rate * error * row[i]
#         print('epoch=',epoch, '\tlrate=',learning_rate,'\terror=',total_error)
#         var_weight = [weights[0],weights[1],weights[2]]
#         weight.append(var_weight)
# #         print(weight)
# #         if (total_error == 0):
# #             count += 1
# #         else: 
# #             count = 0
# #         if (count == 5):
# #             break
        
#     return weight

# %% [markdown]
# ### Estimate Perceptron weights using stochastic gradient descent

# %%
# def train_weights(data_file, learning_rate, epoch_count):
#     # selecting random initial weights
#     weights = np.random.random_sample([data_file.shape[1]])
#     final_weights = []
    
#     for epoch in range(epoch_count):
#         #initialising total error to be 0 for every epochb
#         total_error = 0
        
#         for i in range(len(data_file)):   
            
#             prediction = predict(data_file, weights)
            
#             error = data_file_1.as_matrix()[:,-1][i] - prediction[i]
            
#             total_error += error ** 2   
#             # data file matrix
#             data_matrix = data_file.as_matrix()[:, :-1]
#             # updating bias, bias = bias + lr * error
#             weights[-1] = weights[-1] + learning_rate * error
#             # updating weights
#             for j in range(data_file.shape[1]-1):
#                 weights[j] = weights[j] + learning_rate * error * data_matrix[i][j]
                

#         print('epoch=',epoch, '\tlrate=',learning_rate,'\terror=',total_error)
#         var_weight = [weights[0],weights[1],weights[2]]
#         final_weights.append(var_weight)
#         if (total_error == 0):
#             break
        
#     return final_weights

# %%
# def trainW(data_file, weights, epoch_counts, learning_rate):
#     y_observed = np.array(data_file.loc[:,'y'])
#     data_file_matrix  = data_file.as_matrix()[:,:-1]
#     bias_multiplier =  np.ones(len(data_file_1))
#     data_file_matrix = np.c_[data_file_matrix, bias_multiplier]
#     weight = []
#     for epoch in range(epoch_counts):
#         total_error = 0.0
#         count = 0
#         for row in data_file_matrix:
#             y_predict = np.dot(row,weights)
#             if y_predict > 0:
#                 y_predict = 1
#             else:
#                 y_predict = 0
#             error = y_observed[k] - y_predict
#             count += 1
#             total_error += error**2
#             weights = weights + learning_rate * error * row
#         print('epoch=',epoch, '\tlrate=',learning_rate,'\terror=',total_error)
#         if(total_error == 0.0):
#             break
#         weight.append(weights)
#     return weight

# %%
def predict_y(weights, x_train):
    activation = x_train.dot(weights)
    if activation > 0:
        return 1
    else:
        return 0

# %%
def train(data,lrate=0.01,epochs=100):
    weights = np.random.random_sample(3)
    final_weights = []
    train_x = data.drop(['y'], axis=1)
    train_y = data['y']
    train_x[2] = 1
    train_x = np.array(train_x)
    train_y = np.array(train_y)
    for i in range(epoch_count):
        errorsum = 0
        for x,y in zip(train_x,train_y):
            var_weights = weights
            predicted = predict_y(weights, x)
            error = y - predicted
            errorsum = errorsum + error**2
            weights = weights + x*lrate*error
        print('Iteration=%d, Rate=%.3f, Error=%.1f' % (i, lrate, errorsum))
        final_weights.append(var_weights)
        if errorsum==0:
            print("Converged")
            break
        if i+1==epochs:
            print("Never converges")
    return final_weights

# %% [markdown]
# #### selecting learning rate & epoch count

# %%
learning_rate = 0.1
epoch_count = 50

# %% [markdown]
# #### Getting weights based on train weights function

# %%
weights_1 = train(data_file_1,learning_rate, epoch_count)
# Out:
# Iteration=0, Rate=0.100, Error=13.0
# Iteration=1, Rate=0.100, Error=10.0
# Iteration=2, Rate=0.100, Error=9.0
# Iteration=3, Rate=0.100, Error=10.0
# Iteration=4, Rate=0.100, Error=10.0
# Iteration=5, Rate=0.100, Error=10.0
# Iteration=6, Rate=0.100, Error=10.0
# Iteration=7, Rate=0.100, Error=10.0
# Iteration=8, Rate=0.100, Error=7.0
# Iteration=9, Rate=0.100, Error=9.0
# Iteration=10, Rate=0.100, Error=10.0
# Iteration=11, Rate=0.100, Error=9.0
# Iteration=12, Rate=0.100, Error=11.0
# Iteration=13, Rate=0.100, Error=10.0
# Iteration=14, Rate=0.100, Error=10.0
# Iteration=15, Rate=0.100, Error=10.0
# Iteration=16, Rate=0.100, Error=11.0
# Iteration=17, Rate=0.100, Error=7.0
# Iteration=18, Rate=0.100, Error=10.0
# Iteration=19, Rate=0.100, Error=10.0
# Iteration=20, Rate=0.100, Error=10.0
# Iteration=21, Rate=0.100, Error=9.0
# Iteration=22, Rate=0.100, Error=9.0
# Iteration=23, Rate=0.100, Error=10.0
# Iteration=24, Rate=0.100, Error=10.0
# Iteration=25, Rate=0.100, Error=10.0
# Iteration=26, Rate=0.100, Error=9.0
# Iteration=27, Rate=0.100, Error=7.0
# Iteration=28, Rate=0.100, Error=12.0
# Iteration=29, Rate=0.100, Error=9.0
# Iteration=30, Rate=0.100, Error=10.0
# Iteration=31, Rate=0.100, Error=9.0
# Iteration=32, Rate=0.100, Error=10.0
# Iteration=33, Rate=0.100, Error=10.0
# Iteration=34, Rate=0.100, Error=10.0
# Iteration=35, Rate=0.100, Error=8.0
# Iteration=36, Rate=0.100, Error=11.0
# Iteration=37, Rate=0.100, Error=9.0
# Iteration=38, Rate=0.100, Error=10.0
# Iteration=39, Rate=0.100, Error=10.0
# Iteration=40, Rate=0.100, Error=8.0
# Iteration=41, Rate=0.100, Error=10.0
# Iteration=42, Rate=0.100, Error=10.0
# Iteration=43, Rate=0.100, Error=9.0
# Iteration=44, Rate=0.100, Error=7.0
# Iteration=45, Rate=0.100, Error=12.0
# Iteration=46, Rate=0.100, Error=9.0
# Iteration=47, Rate=0.100, Error=12.0
# Iteration=48, Rate=0.100, Error=10.0
# Iteration=49, Rate=0.100, Error=9.0
# Never converges

# %%
weights_2 = train(data_file_2, learning_rate, epoch_count)
# Out:
# Iteration=0, Rate=0.100, Error=4.0
# Iteration=1, Rate=0.100, Error=1.0
# Iteration=2, Rate=0.100, Error=2.0
# Iteration=3, Rate=0.100, Error=2.0
# Iteration=4, Rate=0.100, Error=2.0
# Iteration=5, Rate=0.100, Error=2.0
# Iteration=6, Rate=0.100, Error=2.0
# Iteration=7, Rate=0.100, Error=0.0
# Converged

# %%
weights_3 = train(data_file_3, learning_rate, epoch_count)
# Out:
# Iteration=0, Rate=0.100, Error=8.0
# Iteration=1, Rate=0.100, Error=2.0
# Iteration=2, Rate=0.100, Error=1.0
# Iteration=3, Rate=0.100, Error=0.0
# Converged

# %%
weights_4 = train(data_file_4, learning_rate, epoch_count)
# Out:
# Iteration=0, Rate=0.100, Error=10.0
# Iteration=1, Rate=0.100, Error=8.0
# Iteration=2, Rate=0.100, Error=9.0
# Iteration=3, Rate=0.100, Error=10.0
# Iteration=4, Rate=0.100, Error=9.0
# Iteration=5, Rate=0.100, Error=10.0
# Iteration=6, Rate=0.100, Error=12.0
# Iteration=7, Rate=0.100, Error=8.0
# Iteration=8, Rate=0.100, Error=8.0
# Iteration=9, Rate=0.100, Error=9.0
# Iteration=10, Rate=0.100, Error=11.0
# Iteration=11, Rate=0.100, Error=10.0
# Iteration=12, Rate=0.100, Error=11.0
# Iteration=13, Rate=0.100, Error=9.0
# Iteration=14, Rate=0.100, Error=8.0
# Iteration=15, Rate=0.100, Error=10.0
# Iteration=16, Rate=0.100, Error=12.0
# Iteration=17, Rate=0.100, Error=8.0
# Iteration=18, Rate=0.100, Error=8.0
# Iteration=19, Rate=0.100, Error=8.0
# Iteration=20, Rate=0.100, Error=8.0
# Iteration=21, Rate=0.100, Error=11.0
# Iteration=22, Rate=0.100, Error=12.0
# Iteration=23, Rate=0.100, Error=12.0
# Iteration=24, Rate=0.100, Error=12.0
# Iteration=25, Rate=0.100, Error=12.0
# Iteration=26, Rate=0.100, Error=12.0
# Iteration=27, Rate=0.100, Error=9.0
# Iteration=28, Rate=0.100, Error=12.0
# Iteration=29, Rate=0.100, Error=11.0
# Iteration=30, Rate=0.100, Error=9.0
# Iteration=31, Rate=0.100, Error=8.0
# Iteration=32, Rate=0.100, Error=12.0
# Iteration=33, Rate=0.100, Error=11.0
# Iteration=34, Rate=0.100, Error=9.0
# Iteration=35, Rate=0.100, Error=8.0
# Iteration=36, Rate=0.100, Error=8.0
# Iteration=37, Rate=0.100, Error=8.0
# Iteration=38, Rate=0.100, Error=8.0
# Iteration=39, Rate=0.100, Error=12.0
# Iteration=40, Rate=0.100, Error=8.0
# Iteration=41, Rate=0.100, Error=11.0
# Iteration=42, Rate=0.100, Error=9.0
# Iteration=43, Rate=0.100, Error=10.0
# Iteration=44, Rate=0.100, Error=12.0
# Iteration=45, Rate=0.100, Error=8.0
# Iteration=46, Rate=0.100, Error=8.0
# Iteration=47, Rate=0.100, Error=10.0
# Iteration=48, Rate=0.100, Error=12.0
# Iteration=49, Rate=0.100, Error=8.0
# Never converges

# %% [markdown]
# #### Line function to get the value of y (y = mx + c)

# %%
def line_func(x, weights):
    y = -((weights[-1][0]/weights[-1][1])*x - (weights[-1][2]/weights[-1][1]))
    return y

# %%
# for plotting the graph of line
x = np.arange(-4,4)
y = line_func(x, weights_1)
plt.plot(x,y, color = 'r', label='hyperline')
plt.scatter(x = data_file_1[data_file_1['y']==0].x1, y = data_file_1[data_file_1['y']==0].x2, edgecolors='g', marker = 'X', label='y=0')
plt.scatter(x = data_file_1[data_file_1['y']==1].x1, y = data_file_1[data_file_1['y']==1].x2, edgecolors='m', marker = 'o', label='y=1')
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend()
plt.title('x1 vs x2')
plt.show()

# %%
# for plotting the graph of line
x = np.arange(-4,4)
y = line_func(x, weights_2)
plt.plot(x,y, color = 'r', label='hyperline')
plt.scatter(x = data_file_2[data_file_2['y']==0].x1, y = data_file_2[data_file_2['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_2[data_file_2['y']==1].x1, y = data_file_2[data_file_2['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')
plt.xlabel('X1')
plt.ylabel('X2')
 
plt.title('x1 vs x2')
plt.legend()
plt.show()

# %%
# for plotting the graph of line

x = np.arange(-4,4)
y = line_func(x, weights_3)
plt.plot(x,y, color = 'r', label='hyperline')
plt.scatter(x = data_file_3[data_file_3['y']==0].x1, y = data_file_3[data_file_3['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_3[data_file_3['y']==1].x1, y = data_file_3[data_file_3['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')
plt.xlabel('X1')
plt.ylabel('X2')
 
plt.legend()
plt.title('x1 vs x2')
plt.show()

# %%
# for plotting the graph of line
x = np.arange(-4,4)
y = line_func(x, weights_4)

plt.scatter(x = data_file_4[data_file_4['y']==0].x1, y = data_file_4[data_file_4['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_4[data_file_4['y']==1].x1, y = data_file_4[data_file_4['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')
plt.xlabel('X1')
plt.ylabel('X2')
 
plt.legend()
plt.title('x1 vs x2')
plt.show()

# %% [markdown]
# ## Animation Plots

# %% [markdown]
# ### Data File 1

# %%
# First set up the figure, the axis, and the plot element we want to animate
# %matplotlib nbagg
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)
x1 = data_file_1['x1']
x2 = data_file_1['x2']
y = data_file_1['y']
w = weights_1
#     plt.scatter(x = data_file[data_file['y']==0].x1, y = data_file_1[data_file['y']==0].x2, edgecolors='g', marker = 'X', label='y=0')
#     plt.scatter(x = data_file[data_file['y']==1].x1, y = data_file_1[data_file['y']==1].x2, edgecolors='m', marker = 'o', label='y=1')
plt.scatter(x1, x2, c= y)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = x1
    y = -((w[i][0]/w[i][1])*x - (w[i][2]/w[i][1]))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(weights_1), interval=200, blit=True, repeat = False)

plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(['hyperline','y=0','y=1'])
plt.title('x1 vs x2')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Data File 2

# %%
# First set up the figure, the axis, and the plot element we want to animate
# %matplotlib nbagg
fig = plt.figure()

ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)
x1 = data_file_2['x1']
x2 = data_file_2['x2']
y = data_file_2['y']
w = weights_2
plt.scatter(x = data_file_2[data_file_2['y']==0].x1, y = data_file_2[data_file_2['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_2[data_file_2['y']==1].x1, y = data_file_2[data_file_2['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')



# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = x1
    y = -((w[i][0]/w[i][1])*x - (w[i][2]/w[i][1]))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(weights_2), interval=20, blit=True, repeat=False)

plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(['hyperline','y=0','y=1'])
plt.title('x1 vs x2')
plt.show()

# %% [markdown]
# ### Data File 3

# %%
# First set up the figure, the axis, and the plot element we want to animate
# %matplotlib nbagg
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)
x1 = data_file_3['x1']
x2 = data_file_3['x2']
y = data_file_3['y']
w = weights_3
plt.scatter(x = data_file_3[data_file_3['y']==0].x1, y = data_file_3[data_file_3['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_3[data_file_3['y']==1].x1, y = data_file_3[data_file_3['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')


# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = x1
    y = -((w[i][0]/w[i][1])*x - (w[i][2]/w[i][1]))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(weights_2), interval=200, blit=True, repeat=False)

plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(['hyperline','y=0','y=1'])
plt.title('x1 vs x2')
plt.show()

# %% [markdown]
# ### Data File 4

# %%
# First set up the figure, the axis, and the plot element we want to animate
# %matplotlib nbagg
fig = plt.figure()
ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)
x1 = data_file_4['x1']
x2 = data_file_4['x2']
y = data_file_4['y']
w = weights_4
plt.scatter(x = data_file_4[data_file_4['y']==0].x1, y = data_file_4[data_file_4['y']==0].x2, edgecolors='g',marker = 'X', label='y=0')
plt.scatter(x = data_file_4[data_file_4['y']==1].x1, y = data_file_4[data_file_4['y']==1].x2, edgecolors='m',marker = 'o', label='y=1')



# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = x1
    y = -((w[i][0]/w[i][1])*x - (w[i][2]/w[i][1]))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(weights_2), interval=200, blit=True, repeat=False)


plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(['hyperline','y=0','y=1'])
plt.title('x1 vs x2')
plt.show()
